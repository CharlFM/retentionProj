# %%
#IMPORT DATA
import pandas as pd
import numpy as np
data_train = pd.read_csv('train.csv')
data_test=pd.read_csv('test.csv')

# %%
data_train.head()
# Out:
#    Retained ID_SALES Program_Code Travel_Type SPR_Product_Type  \
# 0         0   CC139A        other         air       East Coast
# 1         1  CC1600A        other         air       East Coast
# 2         1  CC1836A        other         air       East Coast
# 3         1   CC242A        other         air       East Coast
# 4         0  CC2531A        other         air       East Coast
#
#   GroupGradeTypeLow GroupGradeTypeHigh GroupGradeType MajorProgramCode  \
# 0                PK             Middle     PK->Middle                C
# 1                 K             Middle      K->Middle                C
# 2                PK             Middle     PK->Middle                C
# 3                PK             Middle     PK->Middle                C
# 4                PK             Middle     PK->Middle                C
#
#   Poverty_Code  ... FRP_Take_up_percent_ EZ_Pay_Take_Up_Rate  \
# 0        other  ...             0.570244            0.119431
# 1        other  ...             0.510360            0.190362
# 2        other  ...             0.623850            0.274595
# 3        other  ...             0.592224            0.262095
# 4        other  ...             0.571137            0.088141
#
#   SPR_Group_Revenue  FPP_to_PAX  pol_mean  sub_mean   twl_mean numTweets  \
# 0       2708.000000    0.888166  0.000000  0.000000  31.333333         3
# 1       1250.605592    1.000000  0.000000  0.000000   0.000000         0
# 2       2518.000000    0.929941  0.966667  0.400000  34.333333         3
# 3       2505.000000    0.894531  0.933333  0.733333  57.666667         3
# 4       2569.000000    0.850497  0.000000  0.200000  54.333333         3
#
#   totPaxDiff depositToDeparture
# 0          2         190.000000
# 1          1         199.424613
# 2        -13         164.000000
# 3         -1         162.000000
# 4         -4         195.000000
#
# [5 rows x 54 columns]

# %%
data_test.head()
# Out:
#    Retained ID_SALES Program_Code Travel_Type SPR_Product_Type  \
# 0         1  CC1387A        other         air       East Coast
# 1         1  CC1701A        other         air       East Coast
# 2         1  CC1773A        other         air       East Coast
# 3         0  CC1830A        other         air       East Coast
# 4         1  CC2637A        other         air       East Coast
#
#   GroupGradeTypeLow GroupGradeTypeHigh  GroupGradeType MajorProgramCode  \
# 0                 K               High         K->High                C
# 1                PK             Middle      PK->Middle                C
# 2                 K             Middle       K->Middle                C
# 3            Middle             Middle  Middle->Middle                C
# 4                 K             Middle       K->Middle                C
#
#   Poverty_Code  ... FRP_Take_up_percent_ EZ_Pay_Take_Up_Rate  \
# 0        other  ...             0.345746            0.103222
# 1        other  ...             0.404058            0.104028
# 2        other  ...             0.517738            0.000000
# 3        other  ...             0.721320            0.381479
# 4        other  ...             0.492463            0.168508
#
#   SPR_Group_Revenue  FPP_to_PAX  pol_mean  sub_mean   twl_mean numTweets  \
# 0            2167.0    0.991415  0.766667  0.829167  62.000000         3
# 1            2148.0    0.915161  1.000000  0.533333  44.666667         3
# 2            1989.0    0.866585  1.000000  1.000000  23.000000         3
# 3            2388.0    0.887128  0.000000  0.000000  50.000000         3
# 4            2360.0    0.957977  0.700000  0.800000  23.000000         4
#
#   totPaxDiff depositToDeparture
# 0         -2              320.0
# 1          4              213.0
# 2          1              139.0
# 3        -12              399.0
# 4         -4              207.0
#
# [5 rows x 54 columns]

# %%
#basic statistic details about the data
data_train.describe(include="all")
# Out:
#            Retained ID_SALES Program_Code Travel_Type SPR_Product_Type  \
# count   3229.000000     3229         3229        3229             3229
# unique          NaN     3137            5           2                4
# top             NaN  HD4282A        CN|HD         air       East Coast
# freq            NaN        2         1909        2661             2682
# mean       0.611644      NaN          NaN         NaN              NaN
# std        0.487452      NaN          NaN         NaN              NaN
# min        0.000000      NaN          NaN         NaN              NaN
# 25%        0.000000      NaN          NaN         NaN              NaN
# 50%        1.000000      NaN          NaN         NaN              NaN
# 75%        1.000000      NaN          NaN         NaN              NaN
# max        1.000000      NaN          NaN         NaN              NaN
#
#        GroupGradeTypeLow GroupGradeTypeHigh  GroupGradeType MajorProgramCode  \
# count               3229               3229            3229             3229
# unique                 6                  4              13                4
# top               Middle             Middle  Middle->Middle                H
# freq                1666               2402            1465             2753
# mean                 NaN                NaN             NaN              NaN
# std                  NaN                NaN             NaN              NaN
# min                  NaN                NaN             NaN              NaN
# 25%                  NaN                NaN             NaN              NaN
# 50%                  NaN                NaN             NaN              NaN
# 75%                  NaN                NaN             NaN              NaN
# max                  NaN                NaN             NaN              NaN
#
#        Poverty_Code  ... FRP_Take_up_percent_ EZ_Pay_Take_Up_Rate  \
# count          3229  ...          3229.000000         3229.000000
# unique            5  ...                  NaN                 NaN
# top               B  ...                  NaN                 NaN
# freq           1298  ...                  NaN                 NaN
# mean            NaN  ...             0.567126            0.209859
# std             NaN  ...             0.232677            0.161110
# min             NaN  ...             0.000000            0.000000
# 25%             NaN  ...             0.451581            0.100512
# 50%             NaN  ...             0.595420            0.192580
# 75%             NaN  ...             0.724460            0.296565
# max             NaN  ...             1.049834            1.970037
#
#        SPR_Group_Revenue   FPP_to_PAX     pol_mean     sub_mean     twl_mean  \
# count        3229.000000  3229.000000  3229.000000  3229.000000  3229.000000
# unique               NaN          NaN          NaN          NaN          NaN
# top                  NaN          NaN          NaN          NaN          NaN
# freq                 NaN          NaN          NaN          NaN          NaN
# mean         1593.159208     0.901182     0.059056     0.346663    48.949030
# std           669.146409     0.056090     0.284144     0.267200    14.273453
# min            73.000000     0.608229    -1.000000     0.000000     0.000000
# 25%          1070.000000     0.873556    -0.016667     0.066667    39.333333
# 50%          1679.000000     0.907843     0.000000     0.333333    49.666667
# 75%          2055.000000     0.937686     0.200000     0.559722    59.333333
# max          4610.000000     1.049504     1.000000     1.000000    93.666667
#
#           numTweets   totPaxDiff depositToDeparture
# count   3229.000000  3229.000000        3229.000000
# unique          NaN          NaN                NaN
# top             NaN          NaN                NaN
# freq            NaN          NaN                NaN
# mean       3.054196    -0.176835         195.345928
# std        0.257186     5.836794          49.331680
# min        0.000000   -43.000000        -149.000000
# 25%        3.000000    -2.000000         162.000000
# 50%        3.000000     0.000000         197.000000
# 75%        3.000000     2.000000         225.000000
# max        4.000000    45.000000         584.000000
#
# [11 rows x 54 columns]

# %%
#Separate X and y (explanatory variables and target variable in train set)
X_train = data_train.iloc[:,2:]
column_names = list(X_train) 
Y_train = data_train.iloc[:,0] 
del X_train['Retained_class']
X_train.head()
# Out:
#   Program_Code Travel_Type SPR_Product_Type GroupGradeTypeLow  \
# 0        other         air       East Coast                PK
# 1        other         air       East Coast                 K
# 2        other         air       East Coast                PK
# 3        other         air       East Coast                PK
# 4        other         air       East Coast                PK
#
#   GroupGradeTypeHigh GroupGradeType MajorProgramCode Poverty_Code  \
# 0             Middle     PK->Middle                C        other
# 1             Middle      K->Middle                C        other
# 2             Middle     PK->Middle                C        other
# 3             Middle     PK->Middle                C        other
# 4             Middle     PK->Middle                C        other
#
#                 Region CRM_Segment  ... FRP_Take_up_percent_  \
# 0  Northern California           9  ...             0.570244
# 1                other       other  ...             0.510360
# 2  Northern California           5  ...             0.623850
# 3  Northern California           5  ...             0.592224
# 4  Northern California           9  ...             0.571137
#
#    EZ_Pay_Take_Up_Rate SPR_Group_Revenue  FPP_to_PAX  pol_mean  sub_mean  \
# 0             0.119431       2708.000000    0.888166  0.000000  0.000000
# 1             0.190362       1250.605592    1.000000  0.000000  0.000000
# 2             0.274595       2518.000000    0.929941  0.966667  0.400000
# 3             0.262095       2505.000000    0.894531  0.933333  0.733333
# 4             0.088141       2569.000000    0.850497  0.000000  0.200000
#
#     twl_mean numTweets totPaxDiff  depositToDeparture
# 0  31.333333         3          2          190.000000
# 1   0.000000         0          1          199.424613
# 2  34.333333         3        -13          164.000000
# 3  57.666667         3         -1          162.000000
# 4  54.333333         3         -4          195.000000
#
# [5 rows x 51 columns]

# %%
Y_train.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Retained, dtype: int64

# %%
X_train=pd.get_dummies(X_train,columns=X_train.columns[:31])

# %%
from sklearn.ensemble import RandomForestClassifier

rand_forest = RandomForestClassifier()
rand_forest.fit(X_train, Y_train)

rand_forest
# Out:
# RandomForestClassifier()

# %%
#Separate X and y (explanatory variables and target variable in test set)
X_test = data_test.iloc[:,2:]
column_names = list(X_test) 
Y_test = data_test.iloc[:,0] 
del X_test['Retained_class']
X_test.head()
# Out:
#   Program_Code Travel_Type SPR_Product_Type GroupGradeTypeLow  \
# 0        other         air       East Coast                 K
# 1        other         air       East Coast                PK
# 2        other         air       East Coast                 K
# 3        other         air       East Coast            Middle
# 4        other         air       East Coast                 K
#
#   GroupGradeTypeHigh  GroupGradeType MajorProgramCode Poverty_Code  \
# 0               High         K->High                C        other
# 1             Middle      PK->Middle                C        other
# 2             Middle       K->Middle                C        other
# 3             Middle  Middle->Middle                C        other
# 4             Middle       K->Middle                C        other
#
#                 Region CRM_Segment  ... FRP_Take_up_percent_  \
# 0  Southern California          10  ...             0.345746
# 1  Southern California          11  ...             0.404058
# 2    Pacific Northwest           1  ...             0.517738
# 3  Southern California           5  ...             0.721320
# 4  Southern California           5  ...             0.492463
#
#    EZ_Pay_Take_Up_Rate SPR_Group_Revenue  FPP_to_PAX  pol_mean  sub_mean  \
# 0             0.103222            2167.0    0.991415  0.766667  0.829167
# 1             0.104028            2148.0    0.915161  1.000000  0.533333
# 2             0.000000            1989.0    0.866585  1.000000  1.000000
# 3             0.381479            2388.0    0.887128  0.000000  0.000000
# 4             0.168508            2360.0    0.957977  0.700000  0.800000
#
#     twl_mean numTweets totPaxDiff  depositToDeparture
# 0  62.000000         3         -2               320.0
# 1  44.666667         3          4               213.0
# 2  23.000000         3          1               139.0
# 3  50.000000         3        -12               399.0
# 4  23.000000         4         -4               207.0
#
# [5 rows x 51 columns]

# %%
#CREATE DUMMIES VARIABLES
X_test=pd.get_dummies(X_test,columns=X_test.columns[:31])

# %%
missing_cols = set( X_train.columns ) - set( X_test.columns )
#Add a missing column in test set with default value equal to 0
for c in missing_cols:
    X_test[c] = 0
# Ensure the order of column in the test set is in the same order than in train set
X_test = X_test[X_train.columns]

# %%
rand_forest.predict(X_test)
# Out:
# array([1, 1, 1, ..., 1, 0, 0], dtype=int64)

# %%
y_pred = rand_forest.predict(X_test)

# %%
#DEFINE RANDOM FOREST CLASSIFIER and THE PARAMETERS GRID
import numpy as np

classifier = RandomForestClassifier()
parameters = {"n_estimators":[30,70],"criterion":['entropy','gini'],"max_depth":[6,10,20],"min_samples_split":[2,4],"min_samples_leaf":[1,2]}

# %%
#DEFINE THE GRIDSEARCH 
'''
GS perfoms an exhaustive search over specified parameter values for an estimator.
GS uses a Stratified K-Folds cross-validator
(The folds are made by preserving the percentage of samples for each class.)
If refit=True the model is retrained on the whole training set with the best found params
'''
from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(classifier, parameters, cv=3, scoring = 'accuracy', verbose=50, n_jobs=-1, refit=True)

# %%
#TRAIN CLASSIFIER
gs = gs.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   28.6s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   32.7s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   34.0s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   34.4s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:   35.7s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:   35.8s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   35.9s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:   36.2s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:   36.8s
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:   37.0s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:   37.6s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   37.8s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   38.5s
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   39.4s
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:   39.7s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:   40.3s
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:   40.5s
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:   41.6s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   41.8s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:   42.2s
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:   42.6s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   42.6s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   42.8s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:   43.7s
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:   44.2s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:   44.4s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   44.5s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:   44.6s
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:   45.0s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   46.5s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:   47.2s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:   47.4s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:   48.4s
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:   49.5s
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:   49.7s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:   50.6s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   50.6s
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:   50.8s
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:   51.0s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:   51.0s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:   51.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:   52.5s
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:   52.9s
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:   54.2s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:   54.2s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   54.2s
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:   54.7s
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:   54.8s
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:   55.3s
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:   55.4s
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:   55.4s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:   55.8s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   56.0s
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:   56.0s
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:   56.7s
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:   56.9s
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:   57.3s
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:   57.5s
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:   57.5s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   57.6s
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:   58.3s
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:   58.7s
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:   58.9s
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:   58.9s
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:   59.0s
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:   59.4s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 140 out of 144 | elapsed:  1.1min remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done 144 out of 144 | elapsed:  1.2min finished

# %%
#summarize the results of GRIDSEARCH
print('***GRIDSEARCH RESULTS***')

print("Best score: %f using %s" % (gs.best_score_, gs.best_params_))
means = gs.cv_results_['mean_test_score']
stds = gs.cv_results_['std_test_score']
params = gs.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# ***GRIDSEARCH RESULTS***
# Best score: 0.661825 using {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 30}
# 0.603898 (0.080333) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 0.627443 (0.055861) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 70}
# 0.626823 (0.061894) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.617526 (0.069301) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# 0.623103 (0.061468) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# 0.649128 (0.051620) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 30}
# 0.607613 (0.091789) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 70}
# 0.603586 (0.102041) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.601419 (0.084800) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 150}
# 0.619696 (0.078557) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 200}
# 0.634566 (0.065476) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 0.603590 (0.090415) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 70}
# 0.624962 (0.062661) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.612570 (0.074354) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}
# 0.614121 (0.074764) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# 0.632707 (0.063972) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 30}
# 0.611331 (0.080175) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 70}
# 0.618768 (0.063761) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.617528 (0.074367) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 150}
# 0.606066 (0.086880) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 200}
# 0.623415 (0.080625) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 0.629919 (0.095357) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 70}
# 0.634256 (0.092219) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.630541 (0.094174) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# 0.630850 (0.098034) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# 0.634259 (0.072469) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 30}
# 0.637664 (0.078749) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 70}
# 0.619388 (0.095270) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.636734 (0.094970) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 150}
# 0.629610 (0.097509) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 200}
# 0.599254 (0.113585) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 0.648200 (0.072625) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 70}
# 0.626824 (0.098529) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.630849 (0.097041) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}
# 0.630850 (0.090646) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# 0.631784 (0.083011) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 30}
# 0.643552 (0.080783) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 70}
# 0.633014 (0.099437) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.630847 (0.088475) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 150}
# 0.632089 (0.090891) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 200}
# 0.645411 (0.105973) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 0.659353 (0.093871) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 70}
# 0.649749 (0.103663) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.652226 (0.106562) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# 0.646649 (0.098186) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# 0.630850 (0.114217) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 30}
# 0.639213 (0.108129) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 70}
# 0.652844 (0.108479) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.654392 (0.097194) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 150}
# 0.646336 (0.103840) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 200}
# 0.644793 (0.101623) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 0.646963 (0.103680) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 70}
# 0.641385 (0.101624) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.651296 (0.100561) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}
# 0.644170 (0.102069) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# 0.644173 (0.084730) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 30}
# 0.655326 (0.087527) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 70}
# 0.647271 (0.095885) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.646030 (0.106066) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 150}
# 0.654084 (0.094306) with: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 200}
# 0.648819 (0.102582) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 0.655011 (0.107874) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 70}
# 0.648509 (0.111191) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.649439 (0.107094) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# 0.658418 (0.100049) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# 0.639523 (0.101465) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 30}
# 0.649128 (0.105299) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 70}
# 0.652223 (0.104622) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.653154 (0.100986) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 150}
# 0.648819 (0.102454) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 200}
# 0.625275 (0.104073) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 0.637666 (0.106348) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 70}
# 0.647269 (0.100566) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.644482 (0.106714) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}
# 0.653155 (0.102159) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# 0.635495 (0.108606) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 30}
# 0.639218 (0.096885) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 70}
# 0.643860 (0.099159) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.651606 (0.099847) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 150}
# 0.636118 (0.111459) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 200}
# 0.624654 (0.071511) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 0.633637 (0.073172) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 70}
# 0.596773 (0.102729) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.620006 (0.083852) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# 0.622177 (0.067798) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# 0.661825 (0.059389) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 30}
# 0.644169 (0.062480) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 70}
# 0.618456 (0.065417) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.612881 (0.082079) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 150}
# 0.622487 (0.079338) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 200}
# 0.628686 (0.073843) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 0.625275 (0.082200) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 70}
# 0.606377 (0.087130) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.616291 (0.089939) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}
# 0.626513 (0.059689) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# 0.620317 (0.077472) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 30}
# 0.627443 (0.086670) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 70}
# 0.610717 (0.077084) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.632090 (0.061847) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 150}
# 0.629922 (0.064633) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 200}
# 0.651294 (0.082146) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 0.635498 (0.093697) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 70}
# 0.635496 (0.106169) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.641693 (0.102970) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# 0.642625 (0.097535) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# 0.640149 (0.086146) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 30}
# 0.623728 (0.116069) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 70}
# 0.657494 (0.086555) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.639523 (0.094702) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 150}
# 0.631470 (0.098688) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 200}
# 0.633023 (0.099854) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 0.648514 (0.077085) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 70}
# 0.631167 (0.092542) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.647268 (0.095035) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}
# 0.621869 (0.108248) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# 0.642938 (0.094759) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 30}
# 0.632707 (0.094129) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 70}
# 0.622798 (0.099188) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.643554 (0.100139) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 150}
# 0.634257 (0.093555) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 200}
# 0.636432 (0.118659) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 0.645109 (0.114426) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 70}
# 0.647581 (0.108032) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.656874 (0.100765) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# 0.651916 (0.103006) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# 0.642318 (0.114053) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 30}
# 0.655945 (0.098325) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 70}
# 0.659042 (0.096490) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.637669 (0.108060) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 150}
# 0.649437 (0.107643) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 200}
# 0.637979 (0.109511) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 0.642313 (0.113994) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 70}
# 0.634575 (0.114176) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.639214 (0.105190) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}
# 0.643554 (0.106776) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# 0.643869 (0.087944) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 30}
# 0.642004 (0.118038) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 70}
# 0.642003 (0.103628) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.641383 (0.114258) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 150}
# 0.650060 (0.104278) with: {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 200}
# 0.643554 (0.112030) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 30}
# 0.644794 (0.110170) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 70}
# 0.639217 (0.106389) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.659971 (0.112050) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}
# 0.659661 (0.103089) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# 0.653774 (0.104671) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 30}
# 0.646961 (0.109399) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 70}
# 0.643862 (0.117291) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 0.654703 (0.106560) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 150}
# 0.645413 (0.106140) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 200}
# 0.648207 (0.096547) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 30}
# 0.633953 (0.096774) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 70}
# 0.645411 (0.103749) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# 0.653467 (0.103681) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}
# 0.645413 (0.107406) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# 0.638601 (0.109492) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 30}
# 0.648512 (0.104779) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 70}
# 0.655015 (0.089717) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 100}
# 0.648200 (0.109611) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 150}
# 0.648202 (0.109016) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 200}

# %%
#TEST ON  TEST SET 
best_model = gs.best_estimator_
y_pred = best_model.predict(X_test)

# %%
from sklearn.metrics import classification_report,accuracy_score

print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.76      0.83       418
#            1       0.86      0.95      0.91       658
#
#     accuracy                           0.88      1076
#    macro avg       0.89      0.86      0.87      1076
# weighted avg       0.88      0.88      0.88      1076

# %%
print(accuracy_score(Y_test, y_pred))
# Out:
# 0.8782527881040892

# %%
#EVALUATE THE PREDICTION (on the y_test)
from sklearn.metrics import f1_score
print('***RESULTS ON TEST SET***')
print("f1_score: ", f1_score(Y_test, y_pred))
# Out:
# ***RESULTS ON TEST SET***
# f1_score:  0.905551550108147

# %%
# Plot confusion matrix
import seaborn as sns
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(Y_test, y_pred), annot=True, fmt='d', cmap="Reds", cbar=False);

# %%
# ROC curve

from sklearn import metrics

y_probs = rand_forest.predict_proba(X_test) #predict_proba gives the probabilities for the target (0 and 1 in your case) 

fpr, tpr, thresholds=metrics.roc_curve(Y_test,  y_probs[:,1])

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

auc = metrics.roc_auc_score(Y_test, y_probs[:,1])
print('AUC: %.2f' % auc)
# Out:
# AUC: 0.95
