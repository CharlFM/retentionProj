# %%
#IMPORT DATA
import pandas as pd
import numpy as np
data_train = pd.read_csv('train.csv')
data_test=pd.read_csv('test.csv')

# %%
data_train.head()
# Out:
#    Retained ID_SALES Program_Code Travel_Type SPR_Product_Type  \
# 0         0   CC139A        other         air       East Coast
# 1         1  CC1600A        other         air       East Coast
# 2         1  CC1836A        other         air       East Coast
# 3         1   CC242A        other         air       East Coast
# 4         0  CC2531A        other         air       East Coast
#
#   GroupGradeTypeLow GroupGradeTypeHigh GroupGradeType MajorProgramCode  \
# 0                PK             Middle     PK->Middle                C
# 1                 K             Middle      K->Middle                C
# 2                PK             Middle     PK->Middle                C
# 3                PK             Middle     PK->Middle                C
# 4                PK             Middle     PK->Middle                C
#
#   Poverty_Code  ... FRP_Take_up_percent_ EZ_Pay_Take_Up_Rate  \
# 0        other  ...             0.570244            0.119431
# 1        other  ...             0.510360            0.190362
# 2        other  ...             0.623850            0.274595
# 3        other  ...             0.592224            0.262095
# 4        other  ...             0.571137            0.088141
#
#   SPR_Group_Revenue  FPP_to_PAX  pol_mean  sub_mean   twl_mean numTweets  \
# 0       2708.000000    0.888166  0.000000  0.000000  31.333333         3
# 1       1250.605592    1.000000  0.000000  0.000000   0.000000         0
# 2       2518.000000    0.929941  0.966667  0.400000  34.333333         3
# 3       2505.000000    0.894531  0.933333  0.733333  57.666667         3
# 4       2569.000000    0.850497  0.000000  0.200000  54.333333         3
#
#   totPaxDiff depositToDeparture
# 0          2         190.000000
# 1          1         199.424613
# 2        -13         164.000000
# 3         -1         162.000000
# 4         -4         195.000000
#
# [5 rows x 54 columns]

# %%
data_test.head()
# Out:
#    Retained ID_SALES Program_Code Travel_Type SPR_Product_Type  \
# 0         1  CC1387A        other         air       East Coast
# 1         1  CC1701A        other         air       East Coast
# 2         1  CC1773A        other         air       East Coast
# 3         0  CC1830A        other         air       East Coast
# 4         1  CC2637A        other         air       East Coast
#
#   GroupGradeTypeLow GroupGradeTypeHigh  GroupGradeType MajorProgramCode  \
# 0                 K               High         K->High                C
# 1                PK             Middle      PK->Middle                C
# 2                 K             Middle       K->Middle                C
# 3            Middle             Middle  Middle->Middle                C
# 4                 K             Middle       K->Middle                C
#
#   Poverty_Code  ... FRP_Take_up_percent_ EZ_Pay_Take_Up_Rate  \
# 0        other  ...             0.345746            0.103222
# 1        other  ...             0.404058            0.104028
# 2        other  ...             0.517738            0.000000
# 3        other  ...             0.721320            0.381479
# 4        other  ...             0.492463            0.168508
#
#   SPR_Group_Revenue  FPP_to_PAX  pol_mean  sub_mean   twl_mean numTweets  \
# 0            2167.0    0.991415  0.766667  0.829167  62.000000         3
# 1            2148.0    0.915161  1.000000  0.533333  44.666667         3
# 2            1989.0    0.866585  1.000000  1.000000  23.000000         3
# 3            2388.0    0.887128  0.000000  0.000000  50.000000         3
# 4            2360.0    0.957977  0.700000  0.800000  23.000000         4
#
#   totPaxDiff depositToDeparture
# 0         -2              320.0
# 1          4              213.0
# 2          1              139.0
# 3        -12              399.0
# 4         -4              207.0
#
# [5 rows x 54 columns]

# %%
#basic statistic details about the data
data_train.describe(include="all")
# Out:
#            Retained ID_SALES Program_Code Travel_Type SPR_Product_Type  \
# count   3229.000000     3229         3229        3229             3229
# unique          NaN     3137            5           2                4
# top             NaN  HD4570T        CN|HD         air       East Coast
# freq            NaN        2         1909        2661             2682
# mean       0.611644      NaN          NaN         NaN              NaN
# std        0.487452      NaN          NaN         NaN              NaN
# min        0.000000      NaN          NaN         NaN              NaN
# 25%        0.000000      NaN          NaN         NaN              NaN
# 50%        1.000000      NaN          NaN         NaN              NaN
# 75%        1.000000      NaN          NaN         NaN              NaN
# max        1.000000      NaN          NaN         NaN              NaN
#
#        GroupGradeTypeLow GroupGradeTypeHigh  GroupGradeType MajorProgramCode  \
# count               3229               3229            3229             3229
# unique                 6                  4              13                4
# top               Middle             Middle  Middle->Middle                H
# freq                1666               2402            1465             2753
# mean                 NaN                NaN             NaN              NaN
# std                  NaN                NaN             NaN              NaN
# min                  NaN                NaN             NaN              NaN
# 25%                  NaN                NaN             NaN              NaN
# 50%                  NaN                NaN             NaN              NaN
# 75%                  NaN                NaN             NaN              NaN
# max                  NaN                NaN             NaN              NaN
#
#        Poverty_Code  ... FRP_Take_up_percent_ EZ_Pay_Take_Up_Rate  \
# count          3229  ...          3229.000000         3229.000000
# unique            5  ...                  NaN                 NaN
# top               B  ...                  NaN                 NaN
# freq           1298  ...                  NaN                 NaN
# mean            NaN  ...             0.567126            0.209859
# std             NaN  ...             0.232677            0.161110
# min             NaN  ...             0.000000            0.000000
# 25%             NaN  ...             0.451581            0.100512
# 50%             NaN  ...             0.595420            0.192580
# 75%             NaN  ...             0.724460            0.296565
# max             NaN  ...             1.049834            1.970037
#
#        SPR_Group_Revenue   FPP_to_PAX     pol_mean     sub_mean     twl_mean  \
# count        3229.000000  3229.000000  3229.000000  3229.000000  3229.000000
# unique               NaN          NaN          NaN          NaN          NaN
# top                  NaN          NaN          NaN          NaN          NaN
# freq                 NaN          NaN          NaN          NaN          NaN
# mean         1593.159208     0.901182     0.059056     0.346663    48.949030
# std           669.146409     0.056090     0.284144     0.267200    14.273453
# min            73.000000     0.608229    -1.000000     0.000000     0.000000
# 25%          1070.000000     0.873556    -0.016667     0.066667    39.333333
# 50%          1679.000000     0.907843     0.000000     0.333333    49.666667
# 75%          2055.000000     0.937686     0.200000     0.559722    59.333333
# max          4610.000000     1.049504     1.000000     1.000000    93.666667
#
#           numTweets   totPaxDiff depositToDeparture
# count   3229.000000  3229.000000        3229.000000
# unique          NaN          NaN                NaN
# top             NaN          NaN                NaN
# freq            NaN          NaN                NaN
# mean       3.054196    -0.176835         195.345928
# std        0.257186     5.836794          49.331680
# min        0.000000   -43.000000        -149.000000
# 25%        3.000000    -2.000000         162.000000
# 50%        3.000000     0.000000         197.000000
# 75%        3.000000     2.000000         225.000000
# max        4.000000    45.000000         584.000000
#
# [11 rows x 54 columns]

# %%
#Separate X and y (explanatory variables and target variable in train set)
X_train = data_train.iloc[:,2:]
column_names = list(X_train) 
Y_train = data_train.iloc[:,0] 
del X_train['Retained_class']
X_train.head()
# Out:
#   Program_Code Travel_Type SPR_Product_Type GroupGradeTypeLow  \
# 0        other         air       East Coast                PK
# 1        other         air       East Coast                 K
# 2        other         air       East Coast                PK
# 3        other         air       East Coast                PK
# 4        other         air       East Coast                PK
#
#   GroupGradeTypeHigh GroupGradeType MajorProgramCode Poverty_Code  \
# 0             Middle     PK->Middle                C        other
# 1             Middle      K->Middle                C        other
# 2             Middle     PK->Middle                C        other
# 3             Middle     PK->Middle                C        other
# 4             Middle     PK->Middle                C        other
#
#                 Region CRM_Segment  ... FRP_Take_up_percent_  \
# 0  Northern California           9  ...             0.570244
# 1                other       other  ...             0.510360
# 2  Northern California           5  ...             0.623850
# 3  Northern California           5  ...             0.592224
# 4  Northern California           9  ...             0.571137
#
#    EZ_Pay_Take_Up_Rate SPR_Group_Revenue  FPP_to_PAX  pol_mean  sub_mean  \
# 0             0.119431       2708.000000    0.888166  0.000000  0.000000
# 1             0.190362       1250.605592    1.000000  0.000000  0.000000
# 2             0.274595       2518.000000    0.929941  0.966667  0.400000
# 3             0.262095       2505.000000    0.894531  0.933333  0.733333
# 4             0.088141       2569.000000    0.850497  0.000000  0.200000
#
#     twl_mean numTweets totPaxDiff  depositToDeparture
# 0  31.333333         3          2          190.000000
# 1   0.000000         0          1          199.424613
# 2  34.333333         3        -13          164.000000
# 3  57.666667         3         -1          162.000000
# 4  54.333333         3         -4          195.000000
#
# [5 rows x 51 columns]

# %%
Y_train.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Retained, dtype: int64

# %%
X_train_num = X_train.iloc[:,31:]
X_train_num.head()
# Out:
#    Days  Total_Pax  FPP_to_School_enrollment  MDR_Low_Grade  MDR_High_Grade  \
# 0    18         22                  0.173405      -1.000000        8.000000
# 1    13          7                  0.108986       2.137317        7.639715
# 2    33         71                  0.071500      -1.000000        8.000000
# 3    28         61                  0.067304      -1.000000        8.000000
# 4    11         24                  0.165712      -1.000000        8.000000
#
#    Total_School_Enrollment  NumberOfMeetingswithParents  \
# 0               102.000000                     1.000000
# 1               420.230593                     1.012401
# 2               779.000000                     1.000000
# 3               849.000000                     1.000000
# 4               102.000000                     1.000000
#
#    DifferenceTraveltoFirstMeeting  DifferenceTraveltoLastMeeting  \
# 0                      238.000000                     244.000000
# 1                      259.413772                     231.336913
# 2                      179.000000                     184.000000
# 3                      184.000000                     196.000000
# 4                      250.000000                     238.000000
#
#    FRP_Cancelled  FRP_Take_up_percent_  EZ_Pay_Take_Up_Rate  \
# 0       3.000000              0.570244             0.119431
# 1       3.152003              0.510360             0.190362
# 2       1.000000              0.623850             0.274595
# 3       1.000000              0.592224             0.262095
# 4       3.000000              0.571137             0.088141
#
#    SPR_Group_Revenue  FPP_to_PAX  pol_mean  sub_mean   twl_mean  numTweets  \
# 0        2708.000000    0.888166  0.000000  0.000000  31.333333          3
# 1        1250.605592    1.000000  0.000000  0.000000   0.000000          0
# 2        2518.000000    0.929941  0.966667  0.400000  34.333333          3
# 3        2505.000000    0.894531  0.933333  0.733333  57.666667          3
# 4        2569.000000    0.850497  0.000000  0.200000  54.333333          3
#
#    totPaxDiff  depositToDeparture
# 0           2          190.000000
# 1           1          199.424613
# 2         -13          164.000000
# 3          -1          162.000000
# 4          -4          195.000000

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train_num)

# %%
X_scaled = scaler.transform(X_train_num)
X_scaled = pd.DataFrame(X_scaled,columns=X_train_num.columns)

# %%
X_scaled.head()
# Out:
#        Days  Total_Pax  FPP_to_School_enrollment  MDR_Low_Grade  \
# 0  0.413949  -0.405257                  1.316858      -1.392766
# 1 -0.340363  -0.843729                  0.504914      -0.474224
# 2  2.676883   1.027084                  0.032444      -1.392766
# 3  1.922572   0.734769                 -0.020449      -1.392766
# 4 -0.642088  -0.346794                  1.219898      -1.392766
#
#    MDR_High_Grade  Total_School_Enrollment  NumberOfMeetingswithParents  \
# 0       -0.224008                -1.214154                    -0.152846
# 1       -0.428943                -0.471839                    -0.132563
# 2       -0.224008                 0.365039                    -0.152846
# 3       -0.224008                 0.528324                    -0.152846
# 4       -0.224008                -1.214154                    -0.152846
#
#    DifferenceTraveltoFirstMeeting  DifferenceTraveltoLastMeeting  \
# 0                       -0.248905                       0.339865
# 1                        0.030653                       0.091888
# 2                       -1.019153                      -0.835098
# 3                       -0.953878                      -0.600105
# 4                       -0.092244                       0.222369
#
#    FRP_Cancelled  FRP_Take_up_percent_  EZ_Pay_Take_Up_Rate  \
# 0      -0.100863              0.013401            -0.561366
# 1      -0.060880             -0.244007            -0.121039
# 2      -0.626943              0.243827             0.401875
# 3      -0.626943              0.107883             0.324272
# 4      -0.100863              0.017239            -0.755614
#
#    SPR_Group_Revenue  FPP_to_PAX  pol_mean  sub_mean  twl_mean  numTweets  \
# 0           1.666322   -0.232089  -0.20787 -1.297590 -1.234349  -0.210760
# 1          -0.512006    1.762067  -0.20787 -1.297590 -3.429907 -11.877256
# 2           1.382334    0.512822   3.19469  0.199647 -1.024136  -0.210760
# 3           1.362904   -0.118593   3.07736  1.447345  0.610853  -0.210760
# 4           1.458563   -0.903789  -0.20787 -0.548972  0.377283  -0.210760
#
#    totPaxDiff  depositToDeparture
# 0    0.373008           -0.108384
# 1    0.201655            0.082692
# 2   -2.197294           -0.635510
# 3   -0.141052           -0.676058
# 4   -0.655113           -0.007013

# %%
X_train_OK=X_train.copy()
X_train_OK.loc[:,X_train_num.columns]=X_scaled
X_train_OK.head()
# Out:
#   Program_Code Travel_Type SPR_Product_Type GroupGradeTypeLow  \
# 0        other         air       East Coast                PK
# 1        other         air       East Coast                 K
# 2        other         air       East Coast                PK
# 3        other         air       East Coast                PK
# 4        other         air       East Coast                PK
#
#   GroupGradeTypeHigh GroupGradeType MajorProgramCode Poverty_Code  \
# 0             Middle     PK->Middle                C        other
# 1             Middle      K->Middle                C        other
# 2             Middle     PK->Middle                C        other
# 3             Middle     PK->Middle                C        other
# 4             Middle     PK->Middle                C        other
#
#                 Region CRM_Segment  ... FRP_Take_up_percent_  \
# 0  Northern California           9  ...             0.013401
# 1                other       other  ...            -0.244007
# 2  Northern California           5  ...             0.243827
# 3  Northern California           5  ...             0.107883
# 4  Northern California           9  ...             0.017239
#
#    EZ_Pay_Take_Up_Rate SPR_Group_Revenue  FPP_to_PAX pol_mean  sub_mean  \
# 0            -0.561366          1.666322   -0.232089 -0.20787 -1.297590
# 1            -0.121039         -0.512006    1.762067 -0.20787 -1.297590
# 2             0.401875          1.382334    0.512822  3.19469  0.199647
# 3             0.324272          1.362904   -0.118593  3.07736  1.447345
# 4            -0.755614          1.458563   -0.903789 -0.20787 -0.548972
#
#    twl_mean  numTweets totPaxDiff  depositToDeparture
# 0 -1.234349  -0.210760   0.373008           -0.108384
# 1 -3.429907 -11.877256   0.201655            0.082692
# 2 -1.024136  -0.210760  -2.197294           -0.635510
# 3  0.610853  -0.210760  -0.141052           -0.676058
# 4  0.377283  -0.210760  -0.655113           -0.007013
#
# [5 rows x 51 columns]

# %%
X_train_OK=pd.get_dummies(X_train_OK,columns=X_train_OK.columns[:31])

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(C=10, solver='lbfgs', max_iter=200)
model.fit(X_train_OK, Y_train)
# Out:
# C:\Users\giacollo\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=10, max_iter=200)

# %%
#Separate X and y (explanatory variables and target variable in test set)
X_test = data_test.iloc[:,2:]
column_names = list(X_test) 
Y_test = data_test.iloc[:,0] 
del X_test['Retained_class']
X_test.head()
# Out:
#   Program_Code Travel_Type SPR_Product_Type GroupGradeTypeLow  \
# 0        other         air       East Coast                 K
# 1        other         air       East Coast                PK
# 2        other         air       East Coast                 K
# 3        other         air       East Coast            Middle
# 4        other         air       East Coast                 K
#
#   GroupGradeTypeHigh  GroupGradeType MajorProgramCode Poverty_Code  \
# 0               High         K->High                C        other
# 1             Middle      PK->Middle                C        other
# 2             Middle       K->Middle                C        other
# 3             Middle  Middle->Middle                C        other
# 4             Middle       K->Middle                C        other
#
#                 Region CRM_Segment  ... FRP_Take_up_percent_  \
# 0  Southern California          10  ...             0.345746
# 1  Southern California          11  ...             0.404058
# 2    Pacific Northwest           1  ...             0.517738
# 3  Southern California           5  ...             0.721320
# 4  Southern California           5  ...             0.492463
#
#    EZ_Pay_Take_Up_Rate SPR_Group_Revenue  FPP_to_PAX  pol_mean  sub_mean  \
# 0             0.103222            2167.0    0.991415  0.766667  0.829167
# 1             0.104028            2148.0    0.915161  1.000000  0.533333
# 2             0.000000            1989.0    0.866585  1.000000  1.000000
# 3             0.381479            2388.0    0.887128  0.000000  0.000000
# 4             0.168508            2360.0    0.957977  0.700000  0.800000
#
#     twl_mean numTweets totPaxDiff  depositToDeparture
# 0  62.000000         3         -2               320.0
# 1  44.666667         3          4               213.0
# 2  23.000000         3          1               139.0
# 3  50.000000         3        -12               399.0
# 4  23.000000         4         -4               207.0
#
# [5 rows x 51 columns]

# %%
X_test_num = X_test.iloc[:,31:]
X_test_num.head()
# Out:
#    Days  Total_Pax  FPP_to_School_enrollment  MDR_Low_Grade  MDR_High_Grade  \
# 0    24         29                  0.126429            0.0            12.0
# 1    24         25                  0.142807           -1.0             8.0
# 2    13          7                  0.108986            0.0             8.0
# 3    30         69                  0.246745            7.0             8.0
# 4    24         26                  0.113636            0.0             8.0
#
#    Total_School_Enrollment  NumberOfMeetingswithParents  \
# 0                    196.0                          2.0
# 1                    158.0                          1.0
# 2                     55.0                          1.0
# 3                    214.0                          1.0
# 4                    217.0                          2.0
#
#    DifferenceTraveltoFirstMeeting  DifferenceTraveltoLastMeeting  \
# 0                           332.0                          215.0
# 1                           265.0                          254.0
# 2                           180.0                          189.0
# 3                           280.0                          281.0
# 4                           372.0                          250.0
#
#    FRP_Cancelled  FRP_Take_up_percent_  EZ_Pay_Take_Up_Rate  \
# 0            1.0              0.345746             0.103222
# 1            3.0              0.404058             0.104028
# 2            0.0              0.517738             0.000000
# 3            9.0              0.721320             0.381479
# 4            7.0              0.492463             0.168508
#
#    SPR_Group_Revenue  FPP_to_PAX  pol_mean  sub_mean   twl_mean  numTweets  \
# 0             2167.0    0.991415  0.766667  0.829167  62.000000          3
# 1             2148.0    0.915161  1.000000  0.533333  44.666667          3
# 2             1989.0    0.866585  1.000000  1.000000  23.000000          3
# 3             2388.0    0.887128  0.000000  0.000000  50.000000          3
# 4             2360.0    0.957977  0.700000  0.800000  23.000000          4
#
#    totPaxDiff  depositToDeparture
# 0          -2               320.0
# 1           4               213.0
# 2           1               139.0
# 3         -12               399.0
# 4          -4               207.0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train_num)

# %%
X_scaled_test = scaler.transform(X_test_num)
X_scaled_test = pd.DataFrame(X_scaled_test,columns=X_test_num.columns)
X_scaled_test.head()
# Out:
#        Days  Total_Pax  FPP_to_School_enrollment  MDR_Low_Grade  \
# 0  1.319123  -0.200637                  0.724774      -1.099987
# 1  1.319123  -0.317563                  0.931198      -1.392766
# 2 -0.340363  -0.843729                  0.504914      -1.099987
# 3  2.224297   0.968621                  2.241234       0.949469
# 4  1.319123  -0.288331                  0.563528      -1.099987
#
#    MDR_High_Grade  Total_School_Enrollment  NumberOfMeetingswithParents  \
# 0        2.051241                -0.994887                     1.482740
# 1       -0.224008                -1.083527                    -0.152846
# 2       -0.224008                -1.323788                    -0.152846
# 3       -0.224008                -0.952899                    -0.152846
# 4       -0.224008                -0.945901                     1.482740
#
#    DifferenceTraveltoFirstMeeting  DifferenceTraveltoLastMeeting  \
# 0                        0.978271                      -0.228033
# 1                        0.103582                       0.535693
# 2                       -1.006098                      -0.737184
# 3                        0.299408                       1.064426
# 4                        1.500473                       0.457362
#
#    FRP_Cancelled  FRP_Take_up_percent_  EZ_Pay_Take_Up_Rate  \
# 0      -0.626943             -0.951598            -0.661994
# 1      -0.100863             -0.700943            -0.656987
# 2      -0.889982             -0.212293            -1.302783
# 3       1.477376              0.662799             1.065399
# 4       0.951296             -0.320936            -0.256706
#
#    SPR_Group_Revenue  FPP_to_PAX  pol_mean  sub_mean  twl_mean  numTweets  \
# 0           0.857704    1.608977  2.490712  1.806058  0.914494  -0.210760
# 1           0.829305    0.249267  3.312020  0.698726 -0.300069  -0.210760
# 2           0.591652   -0.616906  3.312020  2.445503 -1.818274  -0.210760
# 3           1.188027   -0.250597 -0.207870 -1.297590  0.073643  -0.210760
# 4           1.146176    1.012730  2.256053  1.696884 -1.818274   3.678071
#
#    totPaxDiff  depositToDeparture
# 0   -0.312406            2.527248
# 1    0.715715            0.357920
# 2    0.201655           -1.142362
# 3   -2.025940            4.128901
# 4   -0.655113            0.236276

# %%
X_test_OK=X_test.copy()
X_test_OK.loc[:,X_test_num.columns]=X_scaled_test
X_test_OK.head()
# Out:
#   Program_Code Travel_Type SPR_Product_Type GroupGradeTypeLow  \
# 0        other         air       East Coast                 K
# 1        other         air       East Coast                PK
# 2        other         air       East Coast                 K
# 3        other         air       East Coast            Middle
# 4        other         air       East Coast                 K
#
#   GroupGradeTypeHigh  GroupGradeType MajorProgramCode Poverty_Code  \
# 0               High         K->High                C        other
# 1             Middle      PK->Middle                C        other
# 2             Middle       K->Middle                C        other
# 3             Middle  Middle->Middle                C        other
# 4             Middle       K->Middle                C        other
#
#                 Region CRM_Segment  ... FRP_Take_up_percent_  \
# 0  Southern California          10  ...            -0.951598
# 1  Southern California          11  ...            -0.700943
# 2    Pacific Northwest           1  ...            -0.212293
# 3  Southern California           5  ...             0.662799
# 4  Southern California           5  ...            -0.320936
#
#    EZ_Pay_Take_Up_Rate SPR_Group_Revenue  FPP_to_PAX  pol_mean  sub_mean  \
# 0            -0.661994          0.857704    1.608977  2.490712  1.806058
# 1            -0.656987          0.829305    0.249267  3.312020  0.698726
# 2            -1.302783          0.591652   -0.616906  3.312020  2.445503
# 3             1.065399          1.188027   -0.250597 -0.207870 -1.297590
# 4            -0.256706          1.146176    1.012730  2.256053  1.696884
#
#    twl_mean numTweets totPaxDiff  depositToDeparture
# 0  0.914494 -0.210760  -0.312406            2.527248
# 1 -0.300069 -0.210760   0.715715            0.357920
# 2 -1.818274 -0.210760   0.201655           -1.142362
# 3  0.073643 -0.210760  -2.025940            4.128901
# 4 -1.818274  3.678071  -0.655113            0.236276
#
# [5 rows x 51 columns]

# %%
X_test_OK=pd.get_dummies(X_test_OK,columns=X_test_OK.columns[:31])

# %%
missing_cols = set( X_train_OK.columns ) - set( X_test_OK.columns )
#Add a missing column in test set with default value equal to 0
for c in missing_cols:
    X_test_OK[c] = 0
# Ensure the order of column in the test set is in the same order than in train set
X_test_OK = X_test_OK[X_train_OK.columns]

# %%
model.predict(X_test_OK)
# Out:
# array([1, 1, 1, ..., 1, 0, 0], dtype=int64)

# %%
#DEFINE THE CLASSIFIER and THE PARAMETERS GRID
from sklearn.linear_model import LogisticRegression
import numpy as np

classifier = LogisticRegression()
parameters = {"C":[1e-4,1e-3,1e-2,1e-1,1,10],"penalty":['l1','l2'], "solver": ['newton-cg', 'lbfgs', 'liblinear', 'sag’', 'saga'] }

# %%
#DEFINE THE GRIDSEARCH 
'''
GS perfoms an exhaustive search over specified parameter values for an estimator.
GS uses a Stratified K-Folds cross-validator
(The folds are made by preserving the percentage of samples for each class.)
If refit=True the model is retrained on the whole training set with the best found params
'''
from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(classifier, parameters, cv=3, scoring = 'accuracy', verbose=50, n_jobs=-1, refit=True)

# %%
#TRAIN THE CLASSIFIER
gs = gs.fit(X_train_OK, Y_train)
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   21.8s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   22.2s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   23.7s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   24.3s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   24.3s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   25.6s
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:   26.1s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:   26.8s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:   28.3s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:   29.8s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:   35.8s
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:   36.6s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   36.7s
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:   36.8s
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:   37.4s
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:   37.6s
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:   37.7s
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:   37.8s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:   37.9s
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:   37.9s
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:   37.9s
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:   37.9s
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:   38.1s
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:   38.9s
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   39.1s
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:   39.2s
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:   39.8s
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:   40.2s
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:   40.9s
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:   41.0s
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:   41.1s
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:   41.2s
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:   42.4s
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:   42.5s
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:   44.2s
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:   46.1s
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:   48.1s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   48.2s
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:   48.2s
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:   49.0s
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   49.5s
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:   49.7s
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:   49.9s
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:   49.9s
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:   50.0s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   51.3s
# [Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:   53.0s
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=-1)]: Done 159 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed:   54.7s
# [Parallel(n_jobs=-1)]: Done 163 tasks      | elapsed:   57.9s
# [Parallel(n_jobs=-1)]: Done 164 tasks      | elapsed:   58.9s
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:   59.0s
# [Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed:   59.1s
# [Parallel(n_jobs=-1)]: Done 167 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 169 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 171 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 177 out of 180 | elapsed:  1.1min remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:  1.1min finished

# %%
#summarize the results of the GRIDSEARCH
print('***GRIDSEARCH RESULTS***')

print("Best score: %f using %s" % (gs.best_score_, gs.best_params_))
means = gs.cv_results_['mean_test_score']
stds = gs.cv_results_['std_test_score']
params = gs.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# ***GRIDSEARCH RESULTS***
# Best score: 0.700538 using {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (nan) with: {'C': 0.0001, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 0.0001, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.388356 (0.000170) with: {'C': 0.0001, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (nan) with: {'C': 0.0001, 'penalty': 'l1', 'solver': 'sag’'}
# 0.611644 (0.000170) with: {'C': 0.0001, 'penalty': 'l1', 'solver': 'saga'}
# 0.611644 (0.000170) with: {'C': 0.0001, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.611644 (0.000170) with: {'C': 0.0001, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.626204 (0.014097) with: {'C': 0.0001, 'penalty': 'l2', 'solver': 'liblinear'}
# nan (nan) with: {'C': 0.0001, 'penalty': 'l2', 'solver': 'sag’'}
# 0.611644 (0.000170) with: {'C': 0.0001, 'penalty': 'l2', 'solver': 'saga'}
# nan (nan) with: {'C': 0.001, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 0.001, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.388356 (0.000170) with: {'C': 0.001, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (nan) with: {'C': 0.001, 'penalty': 'l1', 'solver': 'sag’'}
# 0.611644 (0.000170) with: {'C': 0.001, 'penalty': 'l1', 'solver': 'saga'}
# 0.663999 (0.047026) with: {'C': 0.001, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.663999 (0.047026) with: {'C': 0.001, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.656874 (0.053284) with: {'C': 0.001, 'penalty': 'l2', 'solver': 'liblinear'}
# nan (nan) with: {'C': 0.001, 'penalty': 'l2', 'solver': 'sag’'}
# 0.663689 (0.047092) with: {'C': 0.001, 'penalty': 'l2', 'solver': 'saga'}
# nan (nan) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.628062 (0.143650) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (nan) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'sag’'}
# 0.619697 (0.122181) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'saga'}
# 0.661518 (0.115506) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.661518 (0.115506) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.662756 (0.115609) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
# nan (nan) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'sag’'}
# 0.661827 (0.115398) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'saga'}
# nan (nan) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.653460 (0.135216) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (nan) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'sag’'}
# 0.648813 (0.138277) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'saga'}
# 0.667706 (0.116799) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.667706 (0.116799) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.668325 (0.116108) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# nan (nan) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'sag’'}
# 0.668635 (0.116515) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'saga'}
# nan (nan) with: {'C': 1, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 1, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.668941 (0.117902) with: {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (nan) with: {'C': 1, 'penalty': 'l1', 'solver': 'sag’'}
# 0.669561 (0.116848) with: {'C': 1, 'penalty': 'l1', 'solver': 'saga'}
# 0.678853 (0.109540) with: {'C': 1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.680092 (0.109493) with: {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.679782 (0.109405) with: {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# nan (nan) with: {'C': 1, 'penalty': 'l2', 'solver': 'sag’'}
# 0.674207 (0.111232) with: {'C': 1, 'penalty': 'l2', 'solver': 'saga'}
# nan (nan) with: {'C': 10, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (nan) with: {'C': 10, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.700538 (0.082705) with: {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (nan) with: {'C': 10, 'penalty': 'l1', 'solver': 'sag’'}
# 0.677304 (0.108608) with: {'C': 10, 'penalty': 'l1', 'solver': 'saga'}
# 0.693722 (0.090591) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.689694 (0.095119) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.693412 (0.090914) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# nan (nan) with: {'C': 10, 'penalty': 'l2', 'solver': 'sag’'}
# 0.677613 (0.108568) with: {'C': 10, 'penalty': 'l2', 'solver': 'saga'}

# %%
#TEST ON THE TEST SET 
best_model = gs.best_estimator_
y_pred = best_model.predict(X_test_OK)

# %%
#EVALUATE THE PREDICTION (on the y_test)
from sklearn.metrics import f1_score
print('***RESULTS ON TEST SET***')
print("f1_score: ", f1_score(Y_test, y_pred))
# Out:
# ***RESULTS ON TEST SET***
# f1_score:  0.8923533778767632

# %%
#PRINT SOME FURTHER METRICS
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.82       418
#            1       0.87      0.91      0.89       658
#
#     accuracy                           0.87      1076
#    macro avg       0.86      0.85      0.86      1076
# weighted avg       0.86      0.87      0.86      1076

# %%
#CONFUSION MATRIX
from sklearn.metrics import confusion_matrix
print(confusion_matrix(Y_test, y_pred))
# Out:
# [[330  88]
#  [ 57 601]]

# %%
# Plot confusion matrix
# !conda install seaborn
import seaborn as sns
sns.heatmap(confusion_matrix(Y_test, y_pred), annot=True, fmt='d', cmap="Blues");
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
from sklearn import metrics

model = LogisticRegression(C=0.01,solver='lbfgs', max_iter=1000)
model.fit(X_train_OK, Y_train)
y_pred = model.predict(X_test_OK)

y_probs = model.predict_proba(X_test_OK) #predict_proba gives the probabilities for the target (0 and 1 in your case) 

fpr, tpr, thresholds=metrics.roc_curve(Y_test,  y_probs[:,1])

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

auc = metrics.roc_auc_score(Y_test, y_probs[:,1])
print('AUC: %.2f' % auc)
# Out:
# AUC: 0.92
